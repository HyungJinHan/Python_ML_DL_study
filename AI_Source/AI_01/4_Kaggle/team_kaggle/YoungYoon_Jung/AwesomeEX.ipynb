# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model, datasets
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")  # 파일 불러오기

df_test = pd.read_csv('test.csv')

# %%
df = df.drop(['fnlwgt'], axis = 1) # 불필요한 컬럼 지우기

# df_test = df_test.drop(['education', 'fnlwgt'], axis = 1)

# %%
x_data = df.iloc[:,:-1] # = 피처(학습할 데이터)
y_data = df['income'] # 정답,레이블

x_data
# Out:
#           no  age          workclass      education  education-num  \
# 0          1   25            Private           11th              7
# 1          2   39            Private   Some-college             10
# 2          3   35            Private      Bachelors             13
# 3          4   64            Private      Assoc-voc             11
# 4          5   24            Private   Some-college             10
# ...      ...  ...                ...            ...            ...
# 29300  29301   20            Private        HS-grad              9
# 29301  29302   21            Private        HS-grad              9
# 29302  29303   18   Self-emp-not-inc           10th              6
# 29303  29304   33            Private           11th              7
# 29304  29305   65                  ?        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
x_data['workclass'] = np.where(x_data['workclass'] == ' Private' , np.NaN , x_data['workclass'] )
x_data['workclass']= x_data['workclass'].fillna(x_data['workclass'].mode()[0])
x_data
# Out:
#           no  age          workclass      education  education-num  \
# 0          1   25   Self-emp-not-inc           11th              7
# 1          2   39   Self-emp-not-inc   Some-college             10
# 2          3   35   Self-emp-not-inc      Bachelors             13
# 3          4   64   Self-emp-not-inc      Assoc-voc             11
# 4          5   24   Self-emp-not-inc   Some-college             10
# ...      ...  ...                ...            ...            ...
# 29300  29301   20   Self-emp-not-inc        HS-grad              9
# 29301  29302   21   Self-emp-not-inc        HS-grad              9
# 29302  29303   18   Self-emp-not-inc           10th              6
# 29303  29304   33   Self-emp-not-inc           11th              7
# 29304  29305   65                  ?        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
# x_data['workclass'] = x_data['workclass'].astype('category') # 코드 안정을 위해 데이터 타입 변경
# x_data['marital-status'] = x_data['marital-status'].astype('category')
# x_data['occupation'] = x_data['occupation'].astype('category')
# x_data['relationship'] = x_data['relationship'].astype('category')
# x_data['race'] = x_data['race'].astype('category')
# x_data['sex'] =x_data['sex'].astype('category')
# x_data['native-country'] = x_data['native-country'].astype('category')

# %%
# df_test['workclass'] = df_test['workclass'].astype('category')
# df_test['marital-status'] = df_test['marital-status'].astype('category')
# df_test['occupation'] = df_test['occupation'].astype('category')
# df_test['relationship'] = df_test['relationship'].astype('category')
# df_test['race'] = df_test['race'].astype('category')
# df_test['sex'] = df_test['sex'].astype('category')
# df_test['native-country'] = df_test['native-country'].astype('category')

# %%
x_data = pd.get_dummies(x_data) # 원 핫 인코딩
# df_test = pd.get_dummies(df_test)

x_data
# Out:
#           no  age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0          1   25              7             0             0              40
# 1          2   39             10             0          1721              55
# 2          3   35             13             0             0              50
# 3          4   64             11             0             0              40
# 4          5   24             10             0             0              70
# ...      ...  ...            ...           ...           ...             ...
# 29300  29301   20              9             0             0              40
# 29301  29302   21              9             0             0              40
# 29302  29303   18              6             0             0              40
# 29303  29304   33              7             0             0              65
# 29304  29305   65              9             0             0              40
#
# ...

# %%
x_test_data = df_test
# y_test_data = df_test['income'] # 정답,레이블

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_data, y_data, test_size = 0.33, random_state = 6)

# x_test_train, x_test_test, y_train, y_test = model_selection.train_test_split(
#     x_test_data, y_data, test_size = 0.33, random_state = 42)

# %%
x_train.shape
# Out:
# (19634, 107)

# %%
x_test.shape
# Out:
# (9671, 107)

# %%
model = linear_model.LogisticRegression(solver='liblinear') 

model.fit(x_train, y_train)
# print(model.score(x_test,y_test))
# Out:
# LogisticRegression(solver='liblinear')

# %%
pred = model.predict(x_test) # 학습된 알고리즘을 토대로 x_test를 대입한 값을 pred에 저장
score = accuracy_score(y_test, pred) # 정답 y_test 와 pred 가 어느정도 일치하는지 판별하여 수치상으로 표현

print('test score:', score)
# Out:
# test score: 0.8504808189432324
